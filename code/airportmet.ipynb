# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
datasetAirPort = '../data/AirVisual Data Dump.csv'
data = '../data/airportdata.csv'

# %%
final_data = '../data/FinalData.csv'
final_dataset = pd.read_csv(final_data)

# %%
final_dataset.Datetime = pd.to_datetime(final_dataset.Datetime)
final_dataset_karachi = final_dataset[final_dataset.City == "Karachi"]
names = final_dataset_karachi.Name.unique()

final_dataset_karachi.
Date = pd.to_datetime('2018-02-09')

# %%
if_data = final_dataset_karachi[final_dataset_karachi.Datetime>=Date]
if_data.set_index('Datetime')
if_data.sort_values(by=['Datetime'])
# Out:
#        SerialNumber     City                   Name       FirstOnline  \
# 132796      yggpgpl  Karachi  Civic Center, Korangi   30/08/2018 9:00
# 101758      lllm4gm  Karachi            bahadurabad               NaN
# 96840       g6gs9ls  Karachi          Hyderi Market   30/08/2018 9:00
# 92029       cpguxuc  Karachi                 saddar               NaN
# 121076      tlxa6x7  Karachi            Liaquatabad               NaN
# 23216       aj9xpaw  Karachi                Korangi  26/10/2016 13:00
# 57869       rjpamt6  Karachi   karachi - industrial               NaN
# 126408      twa67s6  Karachi           mt khan road               NaN
# 92028       cpguxuc  Karachi                 saddar               NaN
# 57868       rjpamt6  Karachi   karachi - industrial               NaN
# 23215       aj9xpaw  Karachi                Korangi  26/10/2016 13:00
# 126407      twa67s6  Karachi           mt khan road               NaN
# ...

# %%
dataPort = pd.read_csv(datasetAirPort)
data = pd.read_csv(data)
dataPort.info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179749 entries, 0 to 179748
# Data columns (total 14 columns):
# SerialNumber        164788 non-null object
# City                117617 non-null object
# Name                179749 non-null object
# longitude           117617 non-null float64
# latitude            117617 non-null float64
# FirstOnline         117617 non-null object
# Datetime            179749 non-null object
# PM2.5               179749 non-null float64
# USAQI               179749 non-null int64
# CO2                 164788 non-null float64
# Temperature         178250 non-null float64
# RelativeHumidity    178250 non-null float64
# Outdoor PM2.5       120839 non-null float64
# OutdoorUSAQI        120839 non-null float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84925 entries, 0 to 84924
# Data columns (total 11 columns):
# station               84925 non-null object
# ...

# %%
dataPort = dataPort.drop_duplicates()
dataPort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151256 entries, 0 to 179748
# Data columns (total 14 columns):
# SerialNumber        136295 non-null object
# City                95037 non-null object
# Name                151256 non-null object
# longitude           95037 non-null float64
# latitude            95037 non-null float64
# FirstOnline         95037 non-null object
# Datetime            151256 non-null object
# PM2.5               151256 non-null float64
# USAQI               151256 non-null int64
# CO2                 136295 non-null float64
# Temperature         149757 non-null float64
# RelativeHumidity    149757 non-null float64
# Outdoor PM2.5       96106 non-null float64
# OutdoorUSAQI        96106 non-null float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 17.3+ MB

# %%
dataPort.Datetime = pd.to_datetime(dataPort.Datetime)
data.Datetime = pd.to_datetime(data.valid)
data.drop(["valid", "lon", "lat", "gust_mph", "peak_wind_gust_mph"], axis = 1,inplace=True)
dataPort.drop(["Outdoor PM2.5", "OutdoorUSAQI", "FirstOnline"], axis = 1,inplace=True)
dataPort = dataPort[dataPort.City == "Karachi"]
# Out:
# /Users/mudasir/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
data = data[data.station == 'OPKC']

# %%
Date = pd.to_datetime('2018-05-09')
s = dataPort[dataPort.Datetime>=Date]
s.set_index('Datetime')
s.sort_values(by=['Datetime'])
# Out:
#        SerialNumber     City                       Name  longitude   latitude  \
# 126849      g6gs9ls  Karachi              Hyderi Market  67.044090  24.937533
# 115503      ajgclt7  Karachi           Korangi (J-Area)  67.162531  24.834358
# 11230       4ypxth4  Karachi  Defence Housing Authority  67.052941  24.818095
# 115502      ajgclt7  Karachi           Korangi (J-Area)  67.162531  24.834358
# 11229       4ypxth4  Karachi  Defence Housing Authority  67.052941  24.818095
# 126848      g6gs9ls  Karachi              Hyderi Market  67.044090  24.937533
# 115501      ajgclt7  Karachi           Korangi (J-Area)  67.162531  24.834358
# 126847      g6gs9ls  Karachi              Hyderi Market  67.044090  24.937533
# 11228       4ypxth4  Karachi  Defence Housing Authority  67.052941  24.818095
# 11227       4ypxth4  Karachi  Defence Housing Authority  67.052941  24.818095
# 115500      ajgclt7  Karachi           Korangi (J-Area)  67.162531  24.834358
# ...
